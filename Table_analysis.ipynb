# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyasPoduri/Ai/blob/main/Table_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
database = 'database.sqlite'
conn= sqlite3.connect(database)
print('Data opened succesfully')

import pandas as pd

tables = (""" SELECT * FROM sqlite_master WHERE type = 'table' """, conn)
tables
# Out:
# Data opened succesfully
# (" SELECT * FROM sqlite_master WHERE type = 'table' ",
#  <sqlite3.Connection at 0x7ef66100e020>)

# %%
matches = pd.read_sql(""" select * from Match;""", conn)
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Match_Id          577 non-null    int64
#  1   Team_1            577 non-null    int64
#  2   Team_2            577 non-null    int64
#  3   Match_Date        577 non-null    object
#  4   Season_Id         577 non-null    int64
#  5   Venue_Id          577 non-null    int64
#  6   Toss_Winner       577 non-null    int64
#  7   Toss_Decide       577 non-null    int64
#  8   Win_Type          577 non-null    int64
#  9   Win_Margin        568 non-null    float64
#  10  Outcome_type      577 non-null    int64
#  11  Match_Winner      574 non-null    float64
#  12  Man_of_the_Match  574 non-null    float64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 58.7+ KB

# %%
import pandas as pd

tables = (""" SELECT * FROM sqlite_master WHERE type = 'table' """, conn)
tables

teams = pd.read_sql(""" SELECT * FROM Team;""", conn)
teams

matches = pd.read_sql(""" select * from Match;""", conn)
matches


MI_wins = pd.read_sql(""" SELECT * FROM Match
WHERE Match_winner == 7;""", conn)

MI_wins

MI_S8_S9 = pd.read_sql(""" SELECT * FROM Match
WHERE Match_winner == 7 and Season_Id IN (8,9) ;""", conn)\

MI_S8_S9

new_teams = pd.read_sql(""" SELECT * FROM Team
WHERE Team_name LIKE 'De%';""", conn)
new_teams

min_max_margin = pd.read_sql(""" SELECT
MIN(Win_Margin), MAX(Win_Margin)  FROM Match;""", conn)

min_max_margin
# Out:
#    MIN(Win_Margin)  MAX(Win_Margin)
# 0                1              144
